# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("C:\\Users\\saran\\Downloads\\Jupyter\\Groceries_dataset.csv")
data
# Out:
#        Member_number        Date        itemDescription
# 0               1808  21-07-2015         tropical fruit
# 1               2552  05-01-2015             whole milk
# 2               2300  19-09-2015              pip fruit
# 3               1187  12-12-2015       other vegetables
# 4               3037  01-02-2015             whole milk
# ...              ...         ...                    ...
# 38760           4471  08-10-2014          sliced cheese
# 38761           2022  23-02-2014                  candy
# 38762           1097  16-04-2014               cake bar
# 38763           1510  03-12-2014  fruit/vegetable juice
# 38764           1521  26-12-2014               cat food
#
# [38765 rows x 3 columns]

# %%
x = data['itemDescription'].value_counts().sort_values(ascending=False)[:10]

# %%
x
# Out:
# itemDescription
# whole milk          2502
# other vegetables    1898
# rolls/buns          1716
# soda                1514
# yogurt              1334
# root vegetables     1071
# tropical fruit      1032
# bottled water        933
# sausage              924
# citrus fruit         812
# Name: count, dtype: int64

# %%
plt.figure(figsize=(15,10))
plt.ylabel("Count")
sns.barplot(x=x.index,y= x.values)
# Out:
# <Axes: xlabel='itemDescription', ylabel='Count'>

# %%
from mlxtend.frequent_patterns import apriori, association_rules

# %%
data
# Out:
#        Member_number        Date        itemDescription
# 0               1808  21-07-2015         tropical fruit
# 1               2552  05-01-2015             whole milk
# 2               2300  19-09-2015              pip fruit
# 3               1187  12-12-2015       other vegetables
# 4               3037  01-02-2015             whole milk
# ...              ...         ...                    ...
# 38760           4471  08-10-2014          sliced cheese
# 38761           2022  23-02-2014                  candy
# 38762           1097  16-04-2014               cake bar
# 38763           1510  03-12-2014  fruit/vegetable juice
# 38764           1521  26-12-2014               cat food
#
# [38765 rows x 3 columns]

# %%
data['Quantity']=1
data
# Out:
#        Member_number        Date        itemDescription  Quantity
# 0               1808  21-07-2015         tropical fruit         1
# 1               2552  05-01-2015             whole milk         1
# 2               2300  19-09-2015              pip fruit         1
# 3               1187  12-12-2015       other vegetables         1
# 4               3037  01-02-2015             whole milk         1
# ...              ...         ...                    ...       ...
# 38760           4471  08-10-2014          sliced cheese         1
# 38761           2022  23-02-2014                  candy         1
# 38762           1097  16-04-2014               cake bar         1
# 38763           1510  03-12-2014  fruit/vegetable juice         1
# 38764           1521  26-12-2014               cat food         1
#
# [38765 rows x 4 columns]

# %%
#transactions = data.groupby(['Member_number', 'itemDescription']).sum().unstack().reset_index().set_index('Member_number')
transactions = data.groupby(['Member_number', 'itemDescription']).size().unstack().reset_index().set_index('Member_number')

# %%
transactions=transactions.fillna(0)
transactions
# Out:
# itemDescription  Instant food products  UHT-milk  abrasive cleaner  \
# Member_number
# 1000                               0.0       0.0               0.0
# 1001                               0.0       0.0               0.0
# 1002                               0.0       0.0               0.0
# 1003                               0.0       0.0               0.0
# 1004                               0.0       0.0               0.0
# ...                                ...       ...               ...
# 4996                               0.0       0.0               0.0
# 4997                               0.0       0.0               0.0
# 4998                               0.0       0.0               0.0
# 4999                               0.0       0.0               0.0
# 5000                               0.0       0.0               0.0
#
# itemDescription  artif. sweetener  baby cosmetics  bags  baking powder  \
# Member_number
# ...

# %%
def encode(x):
    if x<=0:
        return 0
    elif x>=0:
        return 1
basket = transactions.map(encode)

# %%
basket
# Out:
# itemDescription  Instant food products  UHT-milk  abrasive cleaner  \
# Member_number
# 1000                                 0         0                 0
# 1001                                 0         0                 0
# 1002                                 0         0                 0
# 1003                                 0         0                 0
# 1004                                 0         0                 0
# ...                                ...       ...               ...
# 4996                                 0         0                 0
# 4997                                 0         0                 0
# 4998                                 0         0                 0
# 4999                                 0         0                 0
# 5000                                 0         0                 0
#
# itemDescription  artif. sweetener  baby cosmetics  bags  baking powder  \
# Member_number
# ...

# %%
from mlxtend.frequent_patterns import apriori, association_rules

frequent_itemset = apriori(basket, min_support=0.06, use_colnames=True)
num_itemsets = frequent_itemset
rules = association_rules(frequent_itemset, num_itemsets, metric='lift', min_threshold=1)
# Out:
# C:\Users\saran\AppData\Local\Programs\Python\Python311\Lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:161: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(

# %%
rules.head()
# Out:
#           antecedents         consequents  antecedent support  \
# 0              (beef)        (whole milk)            0.119548
# 1        (whole milk)              (beef)            0.458184
# 2      (bottled beer)  (other vegetables)            0.158799
# 3  (other vegetables)      (bottled beer)            0.376603
# 4      (bottled beer)        (rolls/buns)            0.158799
#
#    consequent support   support  confidence      lift  representativity  \
# 0            0.458184  0.064135    0.536481  1.170886               1.0
# 1            0.119548  0.064135    0.139978  1.170886               1.0
# 2            0.376603  0.068497    0.431341  1.145345               1.0
# 3            0.158799  0.068497    0.181880  1.145345               1.0
# 4            0.349666  0.063109    0.397415  1.136555               1.0
#
#    leverage  conviction  zhangs_metric   jaccard  certainty  kulczynski
# 0  0.009360    1.168919       0.165762  0.124875   0.144508    0.338229
# ...

# %%
rules[(rules['confidence']>0.4) & (rules['lift']>1.14)]
# Out:
#                         antecedents         consequents  antecedent support  \
# 0                            (beef)        (whole milk)            0.119548
# 2                    (bottled beer)  (other vegetables)            0.158799
# 6                    (bottled beer)        (whole milk)            0.158799
# 9                   (bottled water)  (other vegetables)            0.213699
# 14                  (bottled water)        (whole milk)            0.213699
# 20                         (butter)        (whole milk)            0.126475
# 24                    (canned beer)        (rolls/buns)            0.165213
# 26                    (canned beer)        (whole milk)            0.165213
# 36                           (curd)        (whole milk)            0.120831
# 38                  (domestic eggs)        (whole milk)            0.133145
# 40                    (frankfurter)  (other vegetables)            0.137506
# ...
